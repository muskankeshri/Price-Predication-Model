# %%
import pandas as pd

# %%
m = pd.read_pickle('house_price_predictor.pkl')

# %%
m
# Out:
# LinearRegression()

# %%
inc = eval(input('enter the Avg. Area Income:'))
age = eval(input('enter the Avg. Area House Age :'))
room = eval(input('enter the Avg. Area Number of Rooms :'))
pop = eval(input('enter the   Area Population:'))

query = pd.DataFrame({'Avg. Area Income':[inc],'Avg. Area House Age':[age],'Avg. Area Number of Rooms':[room],'Area Population':[pop]})
# Out:
# enter the Avg. Area Income:90000
# enter the Avg. Area House Age :9
# enter the Avg. Area Number of Rooms :9
# enter the   Area Population:90000

# %%
query
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0             90000                    9                          9
#
#    Area Population
# 0            90000

# %%
m.predict(query)
# Out:
# array([3261568.98595567])

# %%
round(m.predict(query)[0],2)
# Out:
# 3261568.99
